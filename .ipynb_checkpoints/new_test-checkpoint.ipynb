# %%
import scraper2 as s
import pandas as pd
import numpy as np
import datetime
from datetime import date, timedelta
import matplotlib.pyplot as plt
import time
from scipy.stats import norm
import seaborn as sns
from yahoo_fin import options
from yahoo_fin.stock_info import *
from yahoo_fin.stock_info import get_data, get_splits
#import mibian
m = s.stockMongo()

# %%
apple = m.get_options("GOOG")
apple.describe()
# Out:
#                  Ask            Bid     Last Price  Open Interest  \
# count  516437.000000  515901.000000  516676.000000  513699.000000
# mean      199.451280     193.646999     192.383041      59.470941
# std       302.214148     299.352627     284.833622     176.237133
# min         0.000000       0.000000       0.010000       0.000000
# 25%         6.100000       3.300000       7.820000       3.000000
# 50%        46.900000      41.200000      54.450000      12.000000
# 75%       288.700000     279.000000     270.990000      42.000000
# max      2190.000000    2177.700000    2224.300000    5312.000000
#
#               Strike         Volume
# count  516676.000000  458617.000000
# mean     1767.463275      12.222212
# std       518.032166      64.182209
# min       520.000000       1.000000
# 25%      1420.000000       1.000000
# 50%      1750.000000       2.000000
# 75%      2102.500000       6.000000
# max      4100.000000    8534.000000

# %%
symbols = m.get_symbols()

# %%
tickers = []
for sym in symbols:
    tickers.append(sym['sym'])

# %%
tickers
# Out:
# ['CLDR',
#  'CKH',
#  'FEYE',
#  'BCE',
#  'GOOG',
#  'ABBV',
#  'ABEO',
#  'BAND',
#  'BBSI',
#  'CIT',
#  'CLB',
#  'CLIR',
#  'ABCB',
#  'NKLA',
#  'ABC',
#  'CLDT',
#  'ATNM',
#  'A',
#  'BCBP',
#  'SOLO',
#  'MGI',
#  'AAL',
#  'AAT',
#  'ABT',
#  'BBVA',
#  'BC',
#  'CLF',
#  'BBBY',
#  'BBW',
#  'AAON',
#  'AB',
#  'CLFD',
#  'CLI',
#  'FATE',
#  'ABTX',
#  'ACA',
#  'ABR',
#  'NBRV',
#  'ABUS',
#  'VRM',
#  'M',
#  'MVIS',
#  'IBM',
#  'AA',
#  'ABG',
#  'ACHC',
#  'ABM',
#  'CLBK',
#  'FR',
#  'CLX',
#  'EBS',
#  'CLNE',
#  'CLW',
#  'NCLH',
#  'WDC',
#  'WDFC',
#  'WERN',
#  'AEG',
#  'AHH',
#  'AIZ',
#  'AL',
#  'ALK',
#  'AMBC',
#  'AME',
#  'AROC',
#  'ASC',
#  'AVT',
#  'KSU',
#  'KTCC',
#  'WBS',
#  'WCC',
#  'ACIW',
#  'AEIS',
#  'AGIO',
#  'AMG',
#  'AMPY',
#  'AMWD',
#  'APTS',
#  'ARC',
#  'AVEO',
#  'EBF',
#  'KOPN',
#  'PINC',
#  'EB',
#  'EBSB',
#  'WFC',
#  'ED',
#  'ADP',
#  'HT',
#  'AGFS',
#  'KRO',
#  'PK',
#  'AIG',
#  'ALSK',
#  'ACIU',
#  'AMNB',
#  'AEO',
#  'AMSWA',
#  'AIV',
#  'ANH',
#  'AON',
#  'ALNY',
#  'APHA',
#  'AMCX',
#  'APLS',
#  'AMRC',
#  'APT',
#  'AMZA',
#  'AUTO',
#  'AVLR',
#  'ANDE',
#  'ANGI',
#  'ARAV',
#  'ARES',
#  'ARNA',
#  'ARWR',
#  'ATCO',
#  'ATHM',
#  'ATLC',
#  'ATNI',
#  'ATNX',
#  'ATSG',
#  'FRBK',
#  'KRP',
#  'TEN',
#  'WEN',
#  'ABEV',
#  'ACLS',
#  'ACRE',
#  'ACTG',
#  'ACWI',
#  'ADMS',
#  'AGM',
#  'AKRO',
#  'ALGT',
#  'AMH',
#  'ANF',
#  'ANSS',
#  'APPN',
#  'APTV',
#  'ARCC',
#  'ASB',
#  'ASH',
#  'ASPS',
#  'ATRS',
#  'AWRE',
#  'ECPG',
#  'HXL',
#  'KPTI',
#  'KRC',
#  'KURA',
#  'NCR',
#  'SBGI',
#  'TGNA',
#  'ACRX',
#  'AGNC',
#  'AGS',
#  'ALSN',
#  'ALTR',
#  'AM',
#  'ATRA',
#  'AVDL',
#  'AXP',
#  'KNL',
#  'MYRG',
#  'SAVA',
#  'TFC',
#  'WBT',
#  'WHD',
#  'ABB',
#  'ADMP',
#  'AGX',
#  'AGYS',
#  'ALL',
#  'AMAT',
#  'ASUR',
#  'AUB',
#  'AVNS',
#  'AVRO',
#  'CLSD',
#  'EBIX',
#  'KNX',
#  'KOD',
#  'KODK',
#  'KRYS',
#  'NBEV',
#  'WHG',
#  'ADM',
#  'ADUS',
#  'AERI',
#  'AKTS',
#  'APAM',
#  'AVYA',
#  'AXNX',
#  'AXTA',
#  'NAV',
#  'NAVB',
#  'TECH',
#  'AGRX',
#  'ALLE',
#  'AMJ',
#  'AMLP',
#  'AMPE',
#  'AMPH',
#  'AOS',
#  'AQMS',
#  'ARCB',
#  'ARDX',
#  'ARKG',
#  'ATKR',
#  'AUDC',
#  'AVGO',
#  'HY',
#  'HVT',
#  'PJT',
#  'SBUX',
#  'AFTY',
#  'ANIP',
#  'APA',
#  'ATEX',
#  'AVID',
#  'AVTR',
#  'ECHO',
#  'KNSA',
#  'NBIX',
#  'NBTB',
#  'PHM',
#  'SATS',
#  'TEX',
#  'ACES',
#  'ACM',
#  'ADSK',
#  'AEM',
#  'AG',
#  'AHT',
#  'AKBA',
#  'ALBO',
#  'ALDX',
#  'AMN',
#  'AMRS',
#  'AMT',
#  'APPF',
#  'ARAY',
#  'ARCO',
#  'ARD',
#  'ARLP',
#  'ARR',
#  'ASYS',
#  'ATEN',
#  'ATVI',
#  'AVAV',
#  'AXU',
#  'CLR',
#  'TGT',
#  'WCN',
#  'ACOR',
#  'ADC',
#  'ADI',
#  'ADPT',
#  'AGG',
#  'AIRG',
#  'AKR',
#  'AMC',
#  'AMED',
#  'AMSF',
#  'ANTE',
#  'ARCH',
#  'ARGT',
#  'AVA',
#  'EA',
#  'PKE',
#  'WDAY',
#  'WETF',
#  'WGO',
#  'AEP',
#  'AGCO',
#  'ALE',
#  'APYX',
#  'ARI',
#  'ARKW',
#  'ASIX',
#  'ATI',
#  'ATRC',
#  'AVB',
#  'AXS',
#  'EAT',
#  'CLNY',
#  'FRTA',
#  'HTH',
#  'HURN',
#  'TEUM',
#  'TEVA',
#  'AAU',
#  'AAXJ',
#  'ACRS',
#  'AFMD',
#  'AIT',
#  'ALKS',
#  'ALT',
#  'ANAB',
#  'APO',
#  'ARA',
#  'ASA',
#  'AWR',
#  'FRT',
#  'KO',
#  'PICO',
#  'TEL',
#  'ACB',
#  'AFYA',
#  'AI',
#  'AMBA',
#  'ANIK',
#  'AP',
#  'APLE',
#  'ARCT',
#  'ARW',
#  'HTA',
#  'HUBG',
#  'NAVI',
#  'PH',
#  'PHX',
#  'PI',
#  'SBBP',
#  'TFX',
#  'ACCO',
#  'AFL',
#  'AGI',
#  'AGLE',
#  'AIR',
#  'AJG',
#  'AKAM',
#  'ARE',
#  'ARLO',
#  'ASHR',
#  'ATEC',
#  'ATOS',
#  'AVY',
#  'AWK',
#  'BBH',
#  'BAP',
#  'BAM',
#  'BAH',
#  'BCPC',
#  'BDN',
#  'BFAM',
#  'BIL',
#  'BDC',
#  'BEN',
#  'BGFV',
#  'BKD',
#  'BCO',
#  'BGS',
#  'BCSF',
#  'BE',
#  'BELFB',
#  'B',
#  'BCOR',
#  'BDSI',
#  'BGNE',
#  'AZN',
#  'AY',
#  'BATRA',
#  'AZZ',
#  'BHVN',
#  'BKE',
#  'BECN',
#  'BILI',
#  'BKCC',
#  'BAC',
#  'BATRK',
#  'BETZ',
#  'BHLB',
#  'BHP',
#  'BDGE',
#  'BB',
#  'BERY',
#  'BHR',
#  'BIG',
#  'BHC',
#  'BIP',
#  'BCLI',
#  'BJRI',
#  'BK',
#  'BEAT',
#  'BG',
#  'BJ',
#  'BKH',
#  'BKR',
#  'BOX',
#  'BLL',
#  'BLFS',
#  'BLDR',
#  'BRKR',
#  'BSET',
#  'BSQR',
#  'CDAY',
#  'CEO',
#  'BNO',
#  'BRKS',
#  'CALM',
#  'CBPO',
#  'CEQP',
#  'CHIX',
#  'BR',
#  'BRG',
#  'BTU',
#  'BX',
#  'CALX',
#  'CASA',
#  'CATB',
#  'CBAY',
#  'CBT',
#  'BLOK',
#  'BPFH',
#  'BRF',
#  'BTAI',
#  'BXMT',
#  'CALA',
#  'CCMP',
#  'CENT',
#  'CFG',
#  'CGEN',
#  'CHGG',
#  'CHIC',
#  'CADE',
#  'CAL',
#  'CAMP',
#  'CARA',
#  'CARG',
#  'BWA',
#  'BXP',
#  'BXS',
#  'CATY',
#  'CBU',
#  'CENX',
#  'CERS',
#  'BLNK',
#  'BLUE',
#  'BNS',
#  'CAAS',
#  'CCEP',
#  'CCOI',
#  'CDEV',
#  'CDNS',
#  'CDZI',
#  'CHD',
#  'BOH',
#  'BOIL',
#  'CATM',
#  'CBB',
#  'CDMO',
#  'CERN',
#  'BLCN',
#  'BMO',
#  'BMRN',
#  'BPYU',
#  'BRFS',
#  'BRMK',
#  'BWXT',
#  'CAMT',
#  'CDR',
#  'CEW',
#  'CHEF',
#  'BRY',
#  'BSM',
#  'BWX',
#  'CAF',
#  'CAKE',
#  'CAPL',
#  'CBOE',
#  'CDXS',
#  'BND',
#  'BMA',
#  'BSBR',
#  'CBRL',
#  'CCI',
#  'CCK',
#  'CCL',
#  'CDK',
#  'CERC',
#  'BPOP',
#  'BUSE',
#  'BV',
#  'BZUN',
#  'CASH',
#  'CASS',
#  'CC',
#  'CEMI',
#  'CEVA',
#  'CGBD',
#  'CHRS',
#  'BKLN',
#  'BMY',
#  'BNED',
#  'BP',
#  'BPT',
#  'BTI',
#  'BW',
#  'CAG',
#  'CCRN',
#  'CE',
#  'CFRX',
#  'BRO',
#  'BSX',
#  'BXRX',
#  'CANE',
#  'CCS',
#  'CDLX',
#  'CDNA',
#  'CFX',
#  'BNTX',
#  'BPMC',
#  'BPMP',
#  'BRBR',
#  'BRKL',
#  'BYD',
#  'CAJ',
#  'CCXI',
#  'CHMA',
#  'CHNG',
#  'BLX',
#  'BMI',
#  'BOOT',
#  'BZQ',
#  'CACI',
#  'CAPR',
#  'CCLP',
#  'CCO',
#  'CEIX',
#  'CELH',
#  'CGC',
#  'CHU',
#  'CIBR',
#  'CMO',
#  'CNHI',
#  'CORN',
#  'CIM',
#  'CNO',
#  'CNOB',
#  'COMM',
#  'CPSI',
#  'CHS',
#  'CM',
#  'CNI',
#  'CPLP',
#  'CPT',
#  'COLM',
#  'CSII',
#  'CSTE',
#  'CTBI',
#  'CSX',
#  'CTLT',
#  'CTB',
#  'CTG',
#  'CNMD',
#  'CRESY',
#  'CRSP',
#  'CRY',
#  'CHUY',
#  'CHT',
#  'CMP',
#  'CMRE',
#  'CMTL',
#  'CNET',
#  'CNX',
#  'CRAI',
#  'CRMD',
#  'CRS',
#  'CSV',
#  'CTAS',
#  'CNK',
#  'CIB',
#  'CMC',
#  'CONE',
#  'CPG',
#  'CRIS',
#  'CRL',
#  'CRON',
#  'CSL',
#  'COTY',
#  'CR',
#  'CTIC',
#  'CIG',
#  'CNTY',
#  'COW',
#  'CPLG',
#  'CIO',
#  'CNP',
#  'COO',
#  'COWN',
#  'CQP',
#  'CRNT',
#  'CSGP',
#  'CMRX',
#  'CMS',
#  'COLL',
#  'COOP',
#  'CTMX',
#  'CRC',
#  'CRVL',
#  'CODI',
#  'COLD',
#  'CONN',
#  'CMCM',
#  'CHRW',
#  'CNNE',
#  'CNST',
#  'CHX',
#  'CO',
#  'CPSS',
#  'CUE',
#  'CYTK',
#  'CUB',
#  'CTXS',
#  'CTVA',
#  'CUZ',
#  'DBA',
#  'CVGW',
#  'CULP',
#  'DAR',
#  'DCP',
#  'DCPH',
#  'CZZ',
#  'CWK',
#  'DAN',
#  'CXW',
#  'D',
#  'DCI',
#  'DDD',
#  'CVEO',
#  'CWCO',
#  'CWEN',
#  'DDM',
#  'CVA',
#  'CTSO',
#  'CVCO',
#  'CXDC',
#  'CVBF',
#  'CVE',
#  'CYH',
#  'CYB',
#  'CZNC',
#  'DB',
#  'DBO',
#  'DCO',
#  'CXP',
#  'DBC',
#  'CVET',
#  'CUTR',
#  'CWST',
#  'CX',
#  'DHC',
#  'DEM',
#  'DHT',
#  'DKL',
#  'DMLP',
#  'DOG',
#  'DUK',
#  'DX',
#  'DSPG',
#  'DTEA',
#  'DVAX',
#  'DSL',
#  'DY',
#  'DEO',
#  'DFE',
#  'DRE',
#  'DS',
#  'DSKE',
#  'DTE',
#  'DXLG',
#  'E',
#  'ECH',
#  'DISCK',
#  'EEMV',
#  'DIOD',
#  'DENN',
#  'DES',
#  'DISCA',
#  'DGRW',
#  'DOC',
#  'DKNG',
#  'DLN',
#  'DON',
#  'DOOR',
#  'DOV',
#  'EET',
#  'DTIL',
#  'EAF',
#  'EDZ',
#  'DRH',
#  'DRNA',
#  'DT',
#  'DLB',
#  'DFIN',
#  'DELL',
#  'DSX',
#  'DXJ',
#  'DGLY',
#  'DHR',
#  'DLTR',
#  'DMRC',
#  'DQ',
#  'EEX',
#  'EDIT',
#  'DHI',
#  'DEA',
#  'DKS',
#  'DECK',
#  'DGII',
#  'DRQ',
#  'ELP',
#  'EGLE',
#  'ENIC',
#  'ENDP',
#  'EFZ',
#  'ENLC',
#  'EHC',
#  'EPRT',
#  'EQT',
#  'ENSG',
#  'EME',
#  'ENV',
#  'ENZ',
#  'EIG',
#  'EMR',
#  'ENR',
#  'ENTA',
#  'EFC',
#  'EFX',
#  'EIGR',
#  'EIDO',
#  'EGHT',
#  'EQR',
#  'EL',
#  'EPAY',
#  'EPD',
#  'EGO',
#  'EGRX',
#  'ENTG',
#  'EPV',
#  'EQNR',
#  'EGP',
#  'EMAN',
#  'EPI',
#  'EPM',
#  'EGY',
#  'EMKR',
#  'ENB',
#  'ENVA',
#  'EPAC',
#  'EPAM',
#  'ENIA',
#  'EVA',
#  'ESPO',
#  'ESS',
#  'ERJ',
#  'ETRN',
#  'EXC',
#  'FEZ',
#  'FFIV',
#  'FLS',
#  'FMBI',
#  'FNB',
#  'FORR',
#  'GE',
#  'GLOP',
#  'GSKY',
#  'ETR',
#  'EWT',
#  'EWU',
#  'FLY',
#  'FORM',
#  'FRC',
#  'FXH',
#  'GL',
#  'GMF',
#  'GMRE',
#  'GMS',
#  'GNMK',
#  'GOEX',
#  'GS',
#  'GSAT',
#  'GTHX',
#  'EVRI',
#  'FENG',
#  'FHB',
#  'FNDX',
#  'FTI',
#  'FXL',
#  'GCO',
#  'GEL',
#  'GLPI',
#  'GNTX',
#  'GREK',
#  'GTES',
#  'EVC',
#  'EVER',
#  'EWI',
#  'EZU',
#  'FHN',
#  'GLYC',
#  'GNCA',
#  'GPC',
#  'GPRK',
#  'GT',
#  'ETM',
#  'EVOP',
#  'FFIC',
#  'FIS',
#  'FIVN',
#  'FLIR',
#  'FLT',
#  'GBCI',
#  'GFL',
#  'GGG',
#  'GIII',
#  'HAE',
#  'HALL',
#  'ESRT',
#  'EWL',
#  'FC',
#  'FENY',
#  'FET',
#  'FFTY',
#  'FHI',
#  'FLEX',
#  'FLO',
#  'FNDE',
#  'FTDR',
#  'GBT',
#  'GDS',
#  'GFF',
#  'GLUU',
#  'GLW',
#  'GSS',
#  'GWW',
#  'HA',
#  'FFBC',
#  'FOXA',
#  'FTEK',
#  'FTV',
#  'FXC',
#  'GILD',
#  'GLT',
#  'GTN',
#  'GWPH',
#  'HACK',
#  'ESTC',
#  'EWBC',
#  'EUFN',
#  'FIDU',
#  'FIZZ',
#  'FN',
#  'FNF',
#  'FTAI',
#  'G',
#  'GGB',
#  'GOL',
#  'GOOS',
#  'GSHD',
#  'ESNT',
#  'EVFM',
#  'EVR',
#  'EWC',
#  'FANH',
#  'FFNW',
#  'FINV',
#  'FLNT',
#  'FM',
#  'FMC',
#  'FOCS',
#  'FUL',
#  'FWONK',
#  'GOLD',
#  'GXG',
#  'HARP',
#  'FIX',
#  'FOSL',
#  'GEN',
#  'GFI',
#  'GLDD',
#  'GPMT',
#  'GPRO',
#  'GRFS',
#  'GVA',
#  'H',
#  'HAIN',
#  'EXPE',
#  'FCBC',
#  'FDUS',
#  'FGEN',
#  'FIBK',
#  'FND',
#  'FTS',
#  'GIL',
#  'GSX',
#  'GTT',
#  'ERF',
#  'EYE',
#  'EZPW',
#  'FAST',
#  'FBT',
#  'FCEL',
#  'FSP',
#  'FXY',
#  'GDDY',
#  'GNK',
#  'EURL',
#  'FBK',
#  'FIVE',
#  'FLWS',
#  'FSK',
#  'FSTR',
#  'FTK',
#  'FXZ',
#  'GATX',
#  'GKOS',
#  'GRBK',
#  'GTE',
#  'GVI',
#  'ESI',
#  'ESPR',
#  'EUM',
#  'EWP',
#  'EWS',
#  'EXTN',
#  'EYPT',
#  'FOLD',
#  'GAIA',
#  'GASS',
#  'GEF',
#  'GILT',
#  'GLNG',
#  'GORO',
#  'GPL',
#  'EWA',
#  'EXEL',
#  'FBC',
#  'FBNC',
#  'FNHC',
#  'FNKO',
#  'FTNT',
#  'FUN',
#  'GLOG',
#  'GNL',
#  'ERY',
#  'EWG',
#  'EWQ',
#  'EWZ',
#  'FAF',
#  'FBHS',
#  'FCFS',
#  'FCN',
#  'FENC',
#  'FICO',
#  'FMX',
#  'FOX',
#  'GHL',
#  'GNRC',
#  'GOVT',
#  'GPX',
#  'GRUB',
#  'HASI',
#  'HEAR',
#  'HCKT',
#  'HBI',
#  'HIL',
#  'HLT',
#  'HPR',
#  'HRTG',
#  'HST',
#  'IDRA',
#  'HP',
#  'HYG',
#  'HGV',
#  'HQY',
#  'HRL',
#  'HZNP',
#  'IBN',
#  'ICMB',
#  'HBM',
#  'HIBB',
#  'ICE',
#  'IDN',
#  'HBP',
#  'HDGE',
#  'HOLX',
#  'HSBC',
#  'HYLD',
#  'IFN',
#  'HEI',
#  'HCSG',
#  'HMY',
#  'HYRE',
#  'HRB',
#  'HTGC',
#  'HUYA',
#  'IAG',
#  ...]
