# %%
import scraper_eod as s
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np
import datetime
from datetime import date, timedelta
import matplotlib.pyplot as plt
import time
from scipy.stats import norm
import seaborn as sns
from yahoo_fin import options
from yahoo_fin.stock_info import *
from yahoo_fin.stock_info import get_data, get_splits
import mibian
import time
m = s.StockMongo()
import indicator as i
# Out:
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)

# %%
a = m.stock_data.options_analisys.find()

# %%
a.count()
# Out:
# C:\Users\ander\AppData\Local\Temp/ipykernel_29860/4086721465.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   a.count()
# 726

# %%
b = list(a)

# %%
c = pd.DataFrame.from_dict(b)

# %%
c['sqr_rel_risk'].hist()
# Out:
# <AxesSubplot:>

# %%
len(c[c['sqr_rel_risk']<-0.4])
# Out:
# 36

# %%
c[c['sqr_rel_risk']<-0.4]
# Out:
#                           _id        y0  sqr_rel_risk  probability        iv  \
# 6    62cbc573359a988d2b5fcba9 -0.115957     -1.295159    -0.007448 -0.041271
# 16   62cbcb78023263c9811de5e0 -0.115957     -1.295159    -0.007448 -0.041271
# 21   62ce60e519fac682f04c2a5f -0.116009     -0.448176    -0.859096 -0.017019
# 25   62ce661219fac682f04c2a67  0.147709     -0.410000    -0.487991 -0.008764
# 30   62ce6ef519fac682f04c2a71  1.191560     -0.423037    -1.117476 -0.019179
# 75   62d4ffe8df30c7b7901723f8  0.846724     -0.416298    -1.058993 -0.009666
# 87   62d65377f541f3925be189fc  0.648258     -0.567844    -1.229555 -0.015458
# 126  62dce970a27e6984c7f9bb10  0.373177     -0.427208    -0.634840 -0.008635
# 148  62e76da3eec7437b75a14b08 -0.753037     -1.049087     0.003648 -0.002178
# 151  62e773e1eec7437b75a14b0e -0.223103     -0.411060    -0.456352  0.004115
# 218  62f34b3556d73bc7bb845320  0.373046     -0.537321    -1.076657 -0.014196
# 241  62f5f22ea83fe85eacb381de  3.130310     -0.801064    -0.001375 -0.001966
# 242  62f5f2aa1792e59f6ea3b363  1.508337     -0.692061    -1.663628 -0.015864
# 243  62f5f3091792e59f6ea3b365  2.180349     -0.485568     0.002716 -2.478058
# 253  62f74a4e25d576fd1ff68cf8  2.492653     -0.425162    -1.004532 -0.039530
# 295  62fddbea9b8d8d8dcdc1b64e  1.508337     -0.692061    -1.663628 -0.015864
# 296  62fddc529b8d8d8dcdc1b650  2.180349     -0.485568     0.002716 -2.478058
# 302  62ff2de227dd2ed3f96a6321  3.130310     -0.801064    -0.001375 -0.001966
# 307  62ff33292cc970bc52fcc5f3  2.492653     -0.425162    -1.004532 -0.039530
# 332  630323ffeb5f8f8bb74ed3aa  0.846724     -0.416298    -1.058993 -0.009666
# 348  6305c8e589c76397f0ed5567  0.373177     -0.427208    -0.634840 -0.008635
# 361  63104c5902cef16257036e47 -0.753037     -1.049087     0.003648 -0.002178
# 364  631052ce02cef16257036e4d -0.223103     -0.411060    -0.456352  0.004115
# 457  631ed11b6bf9005a3a6476bf  3.130310     -0.801064    -0.001375 -0.001966
