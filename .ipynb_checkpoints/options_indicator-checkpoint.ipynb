# %%
import scraper_eod as s
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np
import datetime
from datetime import date, timedelta
import matplotlib.pyplot as plt
import time
from scipy.stats import norm
import seaborn as sns
from yahoo_fin import options
from yahoo_fin.stock_info import *
from yahoo_fin.stock_info import get_data, get_splits
import mibian
import time
m = s.StockMongo()
import indicator as i
# Out:
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)

# %%
start_time = time.time()
op = m.get_options('GOOG')
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 25.45940637588501 seconds ---

# %%
op = op[op['lastTradeDateTime']==op.index]
# Out:
#                ask     bid  change changePercent         contractName  \
# date
# 2022-05-09   971.5   954.0  -32.05       -0.0244  GOOG220520C01300000
# 2022-05-09   811.5   793.8 -337.61       -0.2924  GOOG220520C01460000
# 2022-05-09   377.0   359.0    3.51         0.008  GOOG220520C01900000
# 2022-05-09   339.0   321.6 -137.28       -0.2834  GOOG220520C01940000
# 2022-05-09   283.0   266.0  -50.60       -0.1446  GOOG220520C02000000
# ...            ...     ...     ...           ...                  ...
# 2022-05-20   789.5   770.5   37.17        0.0516  GOOG240119P02900000
# 2022-05-20   831.0   812.0   28.32        0.0368  GOOG240119P02950000
# 2022-05-20   873.0   854.0   43.16        0.0517  GOOG240119P03000000
# 2022-05-20  1774.0  1754.5  624.00        0.5352  GOOG240119P03950000
# 2022-05-20  2324.0  2304.5  165.13        0.0762  GOOG240119P04500000
#
#            contractPeriod contractSize currency  daysBeforeExpiration   delta  \
# date
# 2022-05-09        MONTHLY      REGULAR      USD                    10  0.9941
# 2022-05-09        MONTHLY      REGULAR      USD                    10  0.9932
# 2022-05-09        MONTHLY      REGULAR      USD                    10  0.9445
# 2022-05-09        MONTHLY      REGULAR      USD                    10  0.9260
# 2022-05-09        MONTHLY      REGULAR      USD                    10  0.8917
# ...                   ...          ...      ...                   ...     ...
# 2022-05-20        MONTHLY      REGULAR      USD                   608 -0.7917
# 2022-05-20        MONTHLY      REGULAR      USD                   608 -0.8118
# 2022-05-20        MONTHLY      REGULAR      USD                   608 -0.8314
# 2022-05-20        MONTHLY      REGULAR      USD                   608 -0.9962
# 2022-05-20        MONTHLY      REGULAR      USD                   608 -0.9968
#
#             ... openInterest      rho  strike theoretical   theta  timeValue  \
# date        ...
# 2022-05-09  ...        100.0   0.3874    1300    962.7500 -0.3997        0.0
# 2022-05-09  ...         11.0   0.4351    1460    802.6500 -0.3575        0.0
# 2022-05-09  ...          6.0   0.5329    1900    368.0000 -1.3056        0.0
# 2022-05-09  ...          2.0   0.5316    1940    330.3000 -1.5879        0.0
# 2022-05-09  ...         22.0   0.5250    2000    274.5000 -1.9871        0.0
# ...         ...          ...      ...     ...         ...     ...        ...
# 2022-05-20  ...         14.0 -34.0840    2900    780.0006 -0.1516        0.0
# 2022-05-20  ...          4.0 -34.9451    2950    821.5007 -0.1409        0.0
# 2022-05-20  ...        238.0 -35.7447    3000    863.5000 -0.1296        0.0
# 2022-05-20  ...          7.0 -24.8932    3950   1764.2500 -0.0043        0.0
# 2022-05-20  ...          1.0 -26.7500    4500   2314.2500 -0.0045        0.0
#
#             type   updatedAt    vega  volume
# date
# 2022-05-09  CALL  2022-05-09  0.0662    16.0
# 2022-05-09  CALL  2022-05-09  0.0742     1.0
# 2022-05-09  CALL  2022-05-09  0.4398     2.0
# 2022-05-09  CALL  2022-05-09  0.5501     1.0
# 2022-05-09  CALL  2022-05-09  0.7303     2.0
# ...          ...         ...     ...     ...
# 2022-05-20   PUT  2022-05-20  8.1006     1.0
# 2022-05-20   PUT  2022-05-20  7.6196     1.0
# 2022-05-20   PUT  2022-05-20  7.1075     1.0
# 2022-05-20   PUT  2022-05-20  0.3174     1.0
# 2022-05-20   PUT  2022-05-20  0.2773     1.0
#
# [10208 rows x 28 columns]

# %%
op.head()
# Out:
#                ask     bid  change changePercent         contractName  \
# date
# 2022-05-09  1071.5  1054.0    0.00           NaN  GOOG220520C01200000
# 2022-05-09   971.5   954.0  -32.05       -0.0244  GOOG220520C01300000
# 2022-05-09   951.5   934.0   19.12        0.0152  GOOG220520C01320000
# 2022-05-09   931.5   913.7 -133.67       -0.1077  GOOG220520C01340000
# 2022-05-09   911.5   893.7 -257.42       -0.1701  GOOG220520C01360000
#
#            contractPeriod contractSize currency  daysBeforeExpiration   delta  \
# date
# 2022-05-09        MONTHLY      REGULAR      USD                    10  0.9947
# 2022-05-09        MONTHLY      REGULAR      USD                    10  0.9941
# 2022-05-09        MONTHLY      REGULAR      USD                    10  0.9939
# 2022-05-09        MONTHLY      REGULAR      USD                    10  0.9945
# 2022-05-09        MONTHLY      REGULAR      USD                    10  0.9943
#
#             ... openInterest     rho  strike theoretical   theta  timeValue  \
# date        ...
# 2022-05-09  ...          1.0  0.3577    1200     1062.75 -0.4062        0.0
# 2022-05-09  ...        100.0  0.3874    1300      962.75 -0.3997        0.0
# 2022-05-09  ...         38.0  0.3933    1320      942.75 -0.3983        0.0
# 2022-05-09  ...         46.0  0.3998    1340      922.60 -0.3505        0.0
# 2022-05-09  ...         23.0  0.4057    1360      902.60 -0.3492        0.0
#
#             type   updatedAt    vega  volume
# date
# 2022-05-09  CALL  2022-05-09  0.0594     NaN
# 2022-05-09  CALL  2022-05-09  0.0662    16.0
# 2022-05-09  CALL  2022-05-09  0.0677     1.0
# 2022-05-09  CALL  2022-05-09  0.0622     1.0
# 2022-05-09  CALL  2022-05-09  0.0636     6.0
#
# [5 rows x 28 columns]

# %%
symbols = m.get_symbols()
tickers = []
for sym in symbols:
    tickers.append(sym['sym'])

# %%
o = i.Options('DKNG')
o.options
# Out:
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
#            date   ask   bid  change changePercent         contractName  \
# 0    2022-05-18  6.45  6.30   -6.19       -0.6415  DKNG220520C00007500
# 1    2022-05-18  3.95  3.80    0.50        0.1408  DKNG220520C00010000
# 2    2022-05-18  3.45  3.30    1.10        0.4681  DKNG220520C00010500
# 3    2022-05-18  2.00  1.83    0.03         0.016  DKNG220520C00012000
# 4    2022-05-18  1.53  1.41    0.06        0.0441  DKNG220520C00012500
# ...         ...   ...   ...     ...           ...                  ...
# 7889 2022-07-19  1.47  1.36    0.26        0.2203  DKNG230217C00020000
# 7890 2022-07-19  0.85  0.72    0.00           0.0  DKNG230217C00025000
# 7891 2022-07-19  1.13  0.98    0.07        0.0714  DKNG240119C00040000
# 7892 2022-07-19  0.70  0.66   -0.01       -0.0145  DKNG240119C00050000
# 7893 2022-07-19  0.31  0.20    0.11          0.55  DKNG240119C00090000
#
#      contractPeriod contractSize currency  daysBeforeExpiration  ...  \
# 0           MONTHLY      REGULAR      USD                     1  ...
# 1           MONTHLY      REGULAR      USD                     1  ...
# 2           MONTHLY      REGULAR      USD                     1  ...
# 3           MONTHLY      REGULAR      USD                     1  ...
# 4           MONTHLY      REGULAR      USD                     1  ...
# ...             ...          ...      ...                   ...  ...
# 7889        MONTHLY      REGULAR      USD                   212  ...
# 7890        MONTHLY      REGULAR      USD                   212  ...
# 7891        MONTHLY      REGULAR      USD                   548  ...
# 7892        MONTHLY      REGULAR      USD                   548  ...
# 7893        MONTHLY      REGULAR      USD                   548  ...
#
#       theoretical   theta  timeValue  type   updatedAt    vega  volume  close  \
# 0           6.375 -0.0267          0  CALL  2022-05-18  0.0003   592.0  13.86
# 1           3.875 -0.0242          0  CALL  2022-05-18  0.0004   163.0  13.86
# 2           3.450 -0.0910          0  CALL  2022-05-18  0.0013    38.0  13.86
# 3           1.900 -0.0430          0  CALL  2022-05-18  0.0013    54.0  13.86
# 4           1.420 -0.0528          0  CALL  2022-05-18  0.0018    43.0  13.86
# ...           ...     ...        ...   ...         ...     ...     ...    ...
# 7889        1.440 -0.0072          0  CALL  2022-07-19  0.0386    27.0  13.49
# 7890        0.750 -0.0055          0  CALL  2022-07-19  0.0305    12.0  13.49
# 7891        1.050 -0.0034          0  CALL  2022-07-19  0.0494    13.0  13.49
# 7892        0.680 -0.0027          0  CALL  2022-07-19  0.0395   116.0  13.49
# 7893        0.310 -0.0017          0  CALL  2022-07-19  0.0233    20.0  13.49
#
#      volatility        vix
# 0      1.212514  30.959999
# 1      1.212514  30.959999
# 2      1.212514  30.959999
# 3      1.212514  30.959999
# 4      1.212514  30.959999
# ...         ...        ...
# 7889   0.997348  24.500000
# 7890   0.997348  24.500000
# 7891   0.997348  24.500000
# 7892   0.997348  24.500000
# 7893   0.997348  24.500000
#
# [7894 rows x 32 columns]

# %%
s = o.returns
#s[s.is_won].plot.scatter(x='probability', y='return')
#s.plot.scatter(x='rel_risk', y='return')
s[(s['rel_risk']>0)&(s['rel_risk']<3)&(s['return']>0)&(s['return']<2)].plot.scatter(x='days_to_strike', y='return')
#o.strikeDates[0].volRange
# Out:
# <AxesSubplot:xlabel='days_to_strike', ylabel='return'>

# %%
o.strikeDates[5].volRange[0].condors[4].valid_put_strikes
# Out:
# array([], dtype=float64)

# %%
s
# Out:
#      strike_date return rel_risk  probability  volatility  is_won  \
# 0     2022-06-24   None     None        0.408    0.384469   False
# 1     2022-06-24   None     None        0.544    0.384469   False
# 2     2022-06-24   None     None        0.680    0.384469   False
# 3     2022-06-24   None     None        0.816    0.384469   False
# 4     2022-06-24   None     None        0.952    0.384469   False
# ...          ...    ...      ...          ...         ...     ...
# 2507  2022-08-26   None     None        0.816    0.410604   False
# 2508  2022-08-26   None     None        0.952    0.410604   False
# 2509  2022-08-26   None     None        1.088    0.410604   False
# 2510  2022-08-26   None     None        1.224    0.410604   False
# 2511  2022-08-26   None     None        1.360    0.410604   False
#
#      days_to_strike       iv      iv2  is_lost        vix
# 0              None  38.4469  38.4469    False  34.750000
# 1              None  38.4469  38.4469    False  34.750000
# 2              None  38.4469  38.4469    False  34.750000
# 3              None  38.4469  38.4469    False  34.750000
# 4              None  38.4469  38.4469    False  34.750000
# ...             ...      ...      ...      ...        ...
# 2507           None  41.0604  41.0604    False  25.299999
# 2508           None  41.0604  41.0604    False  25.299999
# 2509           None  41.0604  41.0604    False  25.299999
# 2510           None  41.0604  41.0604    False  25.299999
# 2511           None  41.0604  41.0604    False  25.299999
#
# [2512 rows x 11 columns]

# %%
linear_regressor = LinearRegression()
selection = s[(s['rel_risk']>0)&(s['rel_risk']<3)&(s['return']>0)&(s['return']<2)]
selection['sqr_rel_risk'] = np.log(selection['rel_risk'])
y = selection['return']
x = selection[['sqr_rel_risk', 'probability', 'iv', 'vix', 'days_to_strike']]
linear_regressor.fit(x, y)
# Out:
# C:\Users\ander\AppData\Local\Temp/ipykernel_23856/797529396.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selection['sqr_rel_risk'] = np.log(selection['rel_risk'])
# LinearRegression()

# %%
a = m.stock_data.options_analisys.find()

# %%
a.count()
# Out:
# C:\Users\ander\AppData\Local\Temp/ipykernel_24780/4086721465.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   a.count()
# 104

# %%
b = list(a)

# %%
c = pd.DataFrame.from_dict(b)

# %%
c['sqr_rel_risk'].hist()
# Out:
# <AxesSubplot:>

# %%
len(c[c['sqr_rel_risk']<-0.4])
# Out:
# 7

# %%
c[c['sqr_rel_risk']<-0.4]
# Out:
#                          _id        y0  sqr_rel_risk  probability        iv  \
# 6   62cbc573359a988d2b5fcba9 -0.115957     -1.295159    -0.007448 -0.041271
# 16  62cbcb78023263c9811de5e0 -0.115957     -1.295159    -0.007448 -0.041271
# 21  62ce60e519fac682f04c2a5f -0.116009     -0.448176    -0.859096 -0.017019
# 25  62ce661219fac682f04c2a67  0.147709     -0.410000    -0.487991 -0.008764
# 30  62ce6ef519fac682f04c2a71  1.191560     -0.423037    -1.117476 -0.019179
# 75  62d4ffe8df30c7b7901723f8  0.846724     -0.416298    -1.058993 -0.009666
# 87  62d65377f541f3925be189fc  0.648258     -0.567844    -1.229555 -0.015458
#
#          vix  days_to_strike ticker       date
# 6   0.000626       -0.004252    MGI 2022-07-11
# 16  0.000626       -0.004252    MGI 2022-07-11
# 21  0.045977        0.011540     BE 2022-07-13
# 25  0.038965        0.002106   BILL 2022-07-13
# 30 -0.022803        0.018231     BP 2022-07-13
# 75  0.015211        0.007624   FUBO 2022-07-18
# 87  0.012389        0.009426    LAC 2022-07-19
