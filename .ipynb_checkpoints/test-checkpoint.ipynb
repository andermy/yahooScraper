# %%
import scraper2 as s
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np
import datetime
from datetime import date, timedelta
import matplotlib.pyplot as plt
import time
from scipy.stats import norm
import seaborn as sns
from yahoo_fin import options
from yahoo_fin.stock_info import *
from yahoo_fin.stock_info import get_data, get_splits
import mibian
import time
m = s.stockMongo()
import indicator as i
# Out:
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)

# %%
op = m.stock_data.options_data2.find()
op.count()
# Out:
# C:\Users\ander\AppData\Local\Temp/ipykernel_21720/3622889483.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   op.count()
# 455549

# %%
def dict_parse(df):
    return pd.DataFrame.from_records(df['options'])

# %%
start_time = time.time()
op = m.stock_data.options_data2.find({'sym':tickers[2]})
df = pd.DataFrame.from_records(op)
df1 = df.apply(dict_parse, axis=1)
df1 = pd.concat(df1.tolist())
df1.head()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1852/611340319.py in <module>
#       3 df = pd.DataFrame.from_records(op)
#       4 df1 = df.apply(dict_parse, axis=1)
# ----> 5 df1 = pd.concat(df1.tolist())
#       6 df1.head()
#       7 print("--- %s seconds ---" % (time.time() - start_time))
#
# ~\Documents\yahooScraper\scrape\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5476         ):
#    5477             return self[name]
# -> 5478         return object.__getattribute__(self, name)
#    5479
#    5480     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'tolist'

# %%
start_time = time.time()
ticker = "AAPL"
apple = m.get_options(tickers[2])
apple['time'] = apple['strike-date'] - apple.index
apple['time'] = apple['time'].dt.total_seconds() / (24 * 60 * 60)
apple['Last Trade Date'] = apple['Last Trade Date'].str.slice(stop=10)
apple['Last Trade Date'] = pd.to_datetime(apple['Last Trade Date'], format='%Y-%m-%d')
apple = apple.reset_index()
strike_dates = apple.pivot_table(columns="strike-date", values="date", aggfunc=np.count_nonzero).columns
#strike_dates[6]
apple2 = apple[apple['strike-date']==strike_dates[7]]
#apple2 = apple2[apple2['date']==apple2['Last Trade Date']]
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 2.4161553382873535 seconds ---

# %%
symbols = m.get_symbols()
tickers = []
for sym in symbols:
    tickers.append(sym['sym'])

# %%
tickers[1634]
# Out:
# 'LQDI'

# %%
apple2.tail()
# Out:
#             date % Change    Ask    Bid  Change       Contract Name  \
# 26479 2022-03-06        -  14.10  13.45    0.00  ABT220318P00135000
# 26480 2022-03-06        -  19.45  18.20    0.00  ABT220318P00140000
# 26481 2022-03-06        -  22.90  22.25    0.00  ABT220318P00145000
# 26482 2022-03-06   +0.17%  29.30  28.40    0.05  ABT220318P00150000
# 26483 2022-03-06        -  48.30  46.15    0.00  ABT220318P00170000
#
#       Implied Volatility  Last Price Last Trade Date  Open Interest  Strike  \
# 26479             44.09%       18.47      2022-02-18           82.0   135.0
# 26480             62.74%       18.30      2022-02-25            1.0   140.0
# 26481              0.00%       24.25      2022-01-26            0.0   145.0
# 26482             63.87%       28.70      2022-03-04           80.0   150.0
# 26483              0.00%       49.50      2022-01-28            0.0   170.0
#
#        Volume strike-date type  time
# 26479     1.0  2022-03-18  put  12.0
# 26480     1.0  2022-03-18  put  12.0
# 26481     2.0  2022-03-18  put  12.0
# 26482    40.0  2022-03-18  put  12.0
# 26483     1.0  2022-03-18  put  12.0

# %%
# set stock ticker symbol
stock_symbol = tickers[33]
 
# set date range for historical prices
end_time = date.today()
start_time = end_time - timedelta(days=400)
 
# reformat date range
end = end_time.strftime('%Y-%m-%d')
start = start_time.strftime('%Y-%m-%d')
 
# get daily stock prices over date range
prices = get_data(stock_symbol, start, end, 'daily')
#compute daily returns and 20 day moving historical volatility
window_size = 20
prices['returns']=prices['close'].pct_change()
prices['volatility']=prices['returns'].rolling(window_size).std()*(252**0.5)
prices['date'] = prices.index
prices.tail()
# Out:
#                  open     high        low      close   adjclose    volume  \
# 2022-02-28  17.040001  17.4300  16.549999  17.250000  17.250000  51465700
# 2022-03-01  16.969999  17.0700  16.080000  16.290001  16.290001  50513700
# 2022-03-02  16.500000  16.9200  16.290001  16.370001  16.370001  43654300
# 2022-03-03  16.629999  16.7500  15.610000  15.710000  15.710000  47203500
# 2022-03-04  15.270000  15.4799  14.420000  14.590000  14.590000  76388689
#
#            ticker   returns  volatility       date
# 2022-02-28    AAL -0.012027    0.580146 2022-02-28
# 2022-03-01    AAL -0.055652    0.590278 2022-03-01
# 2022-03-02    AAL  0.004911    0.585035 2022-03-02
# 2022-03-03    AAL -0.040318    0.600462 2022-03-03
# 2022-03-04    AAL -0.071292    0.644494 2022-03-04

# %%
tickers[13] in ['GOOG', 'SOLO', 'ABT', 'CLF', 'MVIS', 'BBBY', 'MGI', 'M', 'ABBV', 'BAND', 'A', 'IBM', 'ABC', 'NKLA', 'AAL']
# Out:
# False

# %%
o = i.Options(tickers[13])
o.options
# Out:
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
#          date % Change   Ask   Bid  Change        Contract Name  \
# 0  2022-01-24  -80.00%  0.05  0.00   -0.04  ABEO220617C00002500
# 1  2022-01-25        -  3.00  1.95    0.00  ABEO220218P00002500
# 2  2022-01-25  -50.00%  0.05  0.00   -0.05  ABEO220318C00002500
# 3  2022-01-25  -64.29%  0.10  0.00   -0.09  ABEO220318C00005000
# 4  2022-01-25        -  0.05  0.00    0.00  ABEO220318C00007500
# ..        ...      ...   ...   ...     ...                  ...
# 57 2022-03-01        -  0.05  0.00    0.00  ABEO220916C00002500
# 58 2022-03-02        -  0.05  0.00    0.00  ABEO220318C00002500
# 59 2022-03-02        -  0.05  0.00    0.00  ABEO220916C00002500
# 60 2022-03-03   -2.22%  2.90  1.40   -0.05  ABEO220414P00002500
# 61 2022-03-03        -  0.10  0.00    0.00  ABEO220916C00002500
#
#     Implied Volatility  Last Price Last Trade Date  Open Interest  Strike  \
# 0               246.88        0.01      2022-01-24           1722     2.5
# 1              1600.00        2.25      2022-01-25              1     2.5
# 2               393.75        0.05      2022-01-25           1754     2.5
# 3               543.75        0.05      2022-01-25             70     5.0
# 4               493.75        0.05      2022-01-25              3     7.5
# ..                 ...         ...             ...            ...     ...
# 57              190.63        0.05      2022-03-01            644     2.5
# 58              637.50        0.05      2022-03-02           1949     2.5
# 59              187.50        0.05      2022-03-02            686     2.5
# 60                0.00        2.20      2022-03-03              3     2.5
# 61              228.13        0.05      2022-03-03            694     2.5
#
#     Volume strike-date  type   time  close  volatility
# 0     16.0  2022-06-17  call  144.0   0.23    0.913002
# 1    121.0  2022-02-18   put   24.0   0.24    0.873764
# 2    200.0  2022-03-18  call   52.0   0.24    0.873764
# 3    222.0  2022-03-18  call   52.0   0.24    0.873764
# 4    215.0  2022-03-18  call   52.0   0.24    0.873764
# ..     ...         ...   ...    ...    ...         ...
# 57    43.0  2022-09-16  call  199.0   0.28    0.923464
# 58    14.0  2022-03-18  call   16.0   0.29    0.892124
# 59    83.0  2022-09-16  call  198.0   0.29    0.892124
# 60     4.0  2022-04-14  call   42.0   0.28    0.860180
# 61    20.0  2022-09-16  call  197.0   0.28    0.860180
#
# [62 rows x 17 columns]

# %%
s = o.returns
#s[s.is_won].plot.scatter(x='probability', y='return')
s.plot.scatter(x='rel_risk', y='return')
#s[(s['rel_risk']>0)&(s['return']>0)].plot.scatter(x='rel_risk', y='return')
#o.strikeDates[0].volRange
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8488/496001768.py in <module>
# ----> 1 s = o.returns
#       2 #s[s.is_won].plot.scatter(x='probability', y='return')
#       3 s.plot.scatter(x='rel_risk', y='return')
#       4 #s[(s['rel_risk']>0)&(s['return']>0)].plot.scatter(x='rel_risk', y='return')
#       5 #o.strikeDates[0].volRange
#
# AttributeError: 'Options' object has no attribute 'returns'

# %%
prices.close.plot()
# Out:
# <AxesSubplot:>

# %%
m.add("SPY")
# Out:
# 'SPY' added to the database

# %%
len(tickers)
# Out:
# 1636
