# %%
import scraper_eod as s
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np
import datetime
from datetime import date, timedelta
import matplotlib.pyplot as plt
import time
from scipy.stats import norm
import seaborn as sns
from yahoo_fin import options
from yahoo_fin.stock_info import *
from yahoo_fin.stock_info import get_data, get_splits
import mibian
import time
m = s.StockMongo()
import indicator_daily as i
# Out:
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)

# %%
o = i.Options('BE')
o.options
# Out:
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
#         date       contractName contractSize contractPeriod currency  type  \
# 0 2022-07-22  BE220916C00018000      REGULAR        MONTHLY      USD  CALL
# 1 2022-07-22  BE220916C00020000      REGULAR        MONTHLY      USD  CALL
# 2 2022-07-22  BE220916C00021000      REGULAR        MONTHLY      USD  CALL
# 3 2022-07-22  BE220916P00015000      REGULAR        MONTHLY      USD   PUT
# 4 2022-07-22  BE220916P00016000      REGULAR        MONTHLY      USD   PUT
#
#   inTheMoney lastTradeDateTime expirationDate  strike  ...     rho  \
# 0      FALSE        2022-07-21     2022-09-16      18  ...  0.0092
# 1      FALSE        2022-07-21     2022-09-16      20  ...  0.0066
# 2      FALSE        2022-07-21     2022-09-16      21  ...  0.0055
# 3      FALSE        2022-07-22     2022-09-16      15  ... -0.0088
# 4      FALSE        2022-07-22     2022-09-16      16  ... -0.0109
#
#    theoretical  intrinsicValue  timeValue   updatedAt  daysBeforeExpiration  \
# 0        1.425               0          0  2022-07-24                    53
# 1        0.825               0          0  2022-07-24                    53
# 2        0.650               0          0  2022-07-24                    53
# 3        1.250               0          0  2022-07-24                    53
# 4        1.690               0          0  2022-07-24                    53
#
#         iv  close  volatility        vix
# 0  77.2348  16.52    0.618244  23.030001
# 1  77.2348  16.52    0.618244  23.030001
# 2  77.2348  16.52    0.618244  23.030001
# 3  77.2348  16.52    0.618244  23.030001
# 4  77.2348  16.52    0.618244  23.030001
#
# [5 rows x 32 columns]

# %%
s = o.returns
#s[s.is_won].plot.scatter(x='probability', y='return')
#s.plot.scatter(x='rel_risk', y='return')
s[(s['rel_risk']>0)&(s['rel_risk']<3)&(s['r']>0)&(s['r']<2)].plot.scatter(x='rel_risk', y='r')
#o.strikeDates[0].volRange
# Out:
# <AxesSubplot:xlabel='rel_risk', ylabel='r'>

# %%
s[(s['rel_risk']>0)&(s['rel_risk']<3)&(s['r']>0)&(s['r']<2)]
# Out:
#    strike_date  rel_risk  high_put  low_call  highStrike  lowStrike      p  \
# 0   2022-08-19  0.010000      0.23      0.48         9.0       20.0  0.408
# 16  2022-11-18  0.275000      0.85      2.75        12.0       22.0  0.408
# 17  2022-11-18  0.275000      0.45      2.75        10.0       22.0  0.544
# 18  2022-11-18  0.066667      0.30      0.55         9.0       30.0  0.680
#
#            r ticker
# 0   1.769941     BE
# 16  1.160603     BE
# 17  1.043766     BE
# 18  1.562024     BE

# %%
#m = s.StockMongo()
analisys = m.stock_data.options_analisys.find()
tickers = []
for a in analisys:
    tickers.append(a['ticker'])

# %%
print("running data aggregation")
returns = []
for tick in tickers:
    try:
        o = i.Options(tick)
        s = o.returns
        s = s[(s['rel_risk']>0)&(s['rel_risk']<3)&(s['r']>0)&(s['r']<2)].copy()
        returns.append(s)
    except:
        print(tick)
# Out:
# running data aggregation
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\indicator_daily.py:289: RuntimeWarning: invalid value encountered in log
#   r = f['y0'] + f['probability']*0.68 * self.vol_factor/0.5 + f['iv']*self.iv + f['vix']*self.vix + f['days_to_strike']*self.days_to_strike + f['sqr_rel_risk']*np.log(self.risk_rel)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# SOLO
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# MGI
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\indicator_daily.py:289: RuntimeWarning: invalid value encountered in log
#   r = f['y0'] + f['probability']*0.68 * self.vol_factor/0.5 + f['iv']*self.iv + f['vix']*self.vix + f['days_to_strike']*self.days_to_strike + f['sqr_rel_risk']*np.log(self.risk_rel)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# SOLO
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# MGI
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# CHWY
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\indicator_daily.py:289: RuntimeWarning: invalid value encountered in log
#   r = f['y0'] + f['probability']*0.68 * self.vol_factor/0.5 + f['iv']*self.iv + f['vix']*self.vix + f['days_to_strike']*self.days_to_strike + f['sqr_rel_risk']*np.log(self.risk_rel)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\indicator_daily.py:289: RuntimeWarning: invalid value encountered in log
#   r = f['y0'] + f['probability']*0.68 * self.vol_factor/0.5 + f['iv']*self.iv + f['vix']*self.vix + f['days_to_strike']*self.days_to_strike + f['sqr_rel_risk']*np.log(self.risk_rel)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\indicator_daily.py:289: RuntimeWarning: invalid value encountered in log
#   r = f['y0'] + f['probability']*0.68 * self.vol_factor/0.5 + f['iv']*self.iv + f['vix']*self.vix + f['days_to_strike']*self.days_to_strike + f['sqr_rel_risk']*np.log(self.risk_rel)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\indicator_daily.py:289: RuntimeWarning: invalid value encountered in log
#   r = f['y0'] + f['probability']*0.68 * self.vol_factor/0.5 + f['iv']*self.iv + f['vix']*self.vix + f['days_to_strike']*self.days_to_strike + f['sqr_rel_risk']*np.log(self.risk_rel)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\indicator_daily.py:289: RuntimeWarning: invalid value encountered in log
#   r = f['y0'] + f['probability']*0.68 * self.vol_factor/0.5 + f['iv']*self.iv + f['vix']*self.vix + f['days_to_strike']*self.days_to_strike + f['sqr_rel_risk']*np.log(self.risk_rel)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\indicator_daily.py:289: RuntimeWarning: divide by zero encountered in log
#   r = f['y0'] + f['probability']*0.68 * self.vol_factor/0.5 + f['iv']*self.iv + f['vix']*self.vix + f['days_to_strike']*self.days_to_strike + f['sqr_rel_risk']*np.log(self.risk_rel)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\indicator_daily.py:289: RuntimeWarning: invalid value encountered in log
#   r = f['y0'] + f['probability']*0.68 * self.vol_factor/0.5 + f['iv']*self.iv + f['vix']*self.vix + f['days_to_strike']*self.days_to_strike + f['sqr_rel_risk']*np.log(self.risk_rel)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)
# C:\Users\ander\Documents\yahooScraper\scrape\lib\site-packages\cryptography\x509\base.py:531: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_pem_x509_certificate(data)

# %%
b = pd.concat(returns)

# %%
b.sort_values(by=['r'])
# Out:
#    strike_date  rel_risk  high_put  low_call  highStrikePut  lowStrikeCall  \
# 0   2022-09-16  0.070000      1.05      0.60           35.0           55.0
# 11  2022-09-16  0.251000      0.35     11.93          125.0          310.0
# 2   2022-09-16  0.041429      0.30      0.25           24.0           60.0
# 10  2022-09-16  0.275000      0.35     17.50          125.0          290.0
# 15  2022-09-16  0.006000      0.02      0.14            3.0           35.0
# ..         ...       ...       ...       ...            ...            ...
# 13  2022-09-16  0.000600      0.09      0.05           55.0          115.0
# 0   2022-09-16  0.005556      1.00      0.50           34.0           80.0
# 12  2022-09-16  0.000600      0.13      0.05           60.0          115.0
# 11  2022-09-16  0.000600      0.13      0.05           60.0          115.0
# 13  2022-09-16  0.002500      0.20      0.04           18.0           41.0
#
#     lowStrikePut  highStrikeCall      p         r ticker
# 0           35.0            60.0  0.408  0.003964    EQT
# 11         125.0           320.0  0.816  0.028700   ENPH
# 2           31.0            65.0  0.680  0.028861    EQT
# 10         135.0           300.0  0.680  0.113093   ENPH
# 15           8.0            37.0  1.360  0.135269    MRO
# ..           ...             ...    ...       ...    ...
# 13          55.0           165.0  1.088  1.681983    TSM
# 0           34.0           125.0  0.408  1.770118    IPI
# 12          60.0           165.0  0.952  1.829545    TSM
# 11          60.0           165.0  0.816  1.977107    TSM
# 13          18.0            45.0  1.088  1.995310     BP
#
# [288 rows x 11 columns]

# %%
c = b[(b['rel_risk']>0.2)&(b['p']>0.5)].copy()

# %%
c.sort_values(by=['r'])
# Out:
#    strike_date  rel_risk  high_put  low_call  highStrikePut  lowStrikeCall  \
# 11  2022-09-16  0.251000      0.35     11.93         125.00         310.00
# 10  2022-09-16  0.275000      0.35     17.50         125.00         290.00
# 9   2022-09-16  0.353333      0.50     22.35         135.00         280.00
# 10  2022-09-16  0.300000      0.05      1.52           5.00          25.00
# 9   2022-09-16  0.316000      0.95      6.05         115.00         210.00
# 9   2022-09-16  0.720000      0.24      1.40          20.00          43.00
# 9   2022-09-16  0.322000      1.21      6.42          85.00         170.00
# 9   2022-09-16  0.308000      0.20      2.35           7.50          22.50
# 10  2022-09-16  0.400000      0.10      0.90          16.00          45.50
# 9   2022-09-16  0.262000      0.64      3.46          45.00          90.00
# 9   2022-09-16  0.306000      0.33      4.26          60.00         120.00
# 10  2022-09-16  0.280000      0.16      1.54          84.00         124.00
# 10  2022-09-16  0.280000      0.16      1.54          84.00         124.00
# 9   2022-09-16  0.336000      0.26      2.50          87.50         120.50
# 9   2022-09-16  0.336000      0.26      2.50          87.50         120.50
# 1   2022-09-16  0.210000      1.75     10.75         335.00         530.00
# 9   2022-09-16  0.209000      0.38      2.45          65.00         110.00
# 9   2022-09-16  0.220000      0.12      0.76          20.00          34.00
# 1   2022-09-02  0.320000      0.04      0.31           9.50          15.00
# 9   2022-09-16  0.260000      0.05      0.43           9.00          15.00
# 10  2022-09-16  0.275000      0.03      1.37           5.00          16.00
# 11  2022-09-16  0.260000      0.07      0.27          13.00          49.00
# 9   2022-09-16  0.270000      2.95      4.95         470.00         580.00
# 9   2022-09-16  0.430000      0.16      1.37           9.00          16.00
# 10  2022-09-16  0.200000      0.26      0.27          20.00          49.00
# 9   2022-09-16  0.488571      2.50     50.30         950.00        1600.00
# 9   2022-09-16  0.216000      0.64      1.65          18.75          43.75
#
#     lowStrikePut  highStrikeCall      p         r ticker
# 11         125.0           320.0  0.816  0.028700   ENPH
# 10         135.0           300.0  0.680  0.113093   ENPH
# 9          150.0           290.0  0.544  0.155554   ENPH
# 10           7.5            27.5  0.680  0.360863   PLUG
# 9          125.0           220.0  0.544  0.366973   CRWD
# 9           20.5            43.5  0.544  0.368669   SHOP
# 9           90.0           175.0  0.544  0.452447   SNOW
# 9           10.0            25.0  0.544  0.470667   PLUG
# 10          16.5            46.0  0.680  0.533438   SHOP
# 9           50.0            95.0  0.544  0.544999     SE
# 9           65.0           125.0  0.544  0.573978   ETSY
# 10          85.0           125.0  0.680  0.622610   GOOG
# 10          85.0           125.0  0.680  0.622610   GOOG
# 9           90.0           123.0  0.544  0.634194   GOOG
# 9           90.0           123.0  0.544  0.634194   GOOG
# 1          360.0           540.0  0.544  0.683309   LRCX
# 9           75.0           120.0  0.544  0.721196     BX
# 9           22.0            36.0  0.544  0.727500    FCX
# 1           10.0            15.5  0.544  0.775789      F
# 9           10.0            16.0  0.544  0.778481      F
# 10           9.0            20.0  0.680  0.805108   CHPT
# 11          14.0            50.0  0.816  0.806496     LI
# 9          480.0           590.0  0.544  0.816076    UNH
# 9           10.0            17.0  0.544  0.830904   CHPT
# 10          21.0            50.0  0.680  0.833411     LI
# 9          985.0          1610.0  0.544  0.866001    CMG
# 9           20.0            45.0  0.544  0.968052    GME
